# %%
from pathlib import Path
import glob
import os
import pandas as pd

# %%
img_path = Path(r'E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files/raw')

# %%
img_list = list(img_path.glob('*.tif'))

# %%
for img in img_list:
    
    file_name = img.name
    split_name = file_name.split('_')
    

    if '3B' in file_name:
        date = pd.to_datetime(split_name[0])
    elif 'BGRN' in file_name or 'BGREN' in file_name:
        date = pd.to_datetime(split_name[2])
    elif 'RE' in file_name:
        date = pd.to_datetime(split_name[1])
    elif 'RGB' in file_name:
        date = pd.to_datetime(split_name[2])
    print(img)
    date = date.strftime('%Y_%m_%d')
    
    img.replace(Path(str(img.parent).replace('raw', 'renamed'))/f'{date}_{img.name}')
# Out:
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\1134910_1843614_2018-02-02_1011_BGRN_DN_udm_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\1228332_1843614_2018-03-02_1022_BGRN_Analytic_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\1228332_1843614_2018-03-02_1022_BGRN_DN_udm_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\1843614_2012-07-27_RE4_3A_Analytic_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\1843614_2012-07-27_RE4_3A_udm_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\1843614_2015-04-22_RE4_3A_Analytic_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\1843614_2015-04-22_RE4_3A_udm_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\1899858_1843614_2018-12-03_0f31_BGRN_Analytic_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\1899858_1843614_2018-12-03_0f31_BGRN_DN_udm_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20170316_144453_0e14_3B_AnalyticMS_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20170316_144453_0e14_3B_AnalyticMS_DN_udm_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20170727_144421_0f12_3B_AnalyticMS_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20170727_144421_0f12_3B_AnalyticMS_DN_udm_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20171218_160102_0f32_3B_AnalyticMS_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20171218_160102_0f32_3B_AnalyticMS_DN_udm_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20180617_153311_0f3b_3B_Analytic_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20180617_153311_0f3b_3B_Analytic_DN_udm_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20181231_150320_1040_3B_AnalyticMS_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20181231_150320_1040_3B_AnalyticMS_DN_udm_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20190206_145831_0f3d_3B_AnalyticMS_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20190206_145831_0f3d_3B_AnalyticMS_DN_udm_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20190703_143711_1049_3B_AnalyticMS_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20190703_143711_1049_3B_AnalyticMS_DN_udm_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20190830_150858_100a_3B_AnalyticMS_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20190830_150858_100a_3B_AnalyticMS_DN_udm_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20200117_152902_70_1058_3B_AnalyticMS_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20200117_152902_70_1058_3B_AnalyticMS_DN_udm_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20200229_150823_103b_3B_AnalyticMS_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20200229_150823_103b_3B_AnalyticMS_DN_udm_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20200325_144012_65_2275_3B_AnalyticMS_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20200325_144012_65_2275_3B_AnalyticMS_DN_udm_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20200523_144252_66_2277_3B_AnalyticMS_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20200523_144252_66_2277_3B_AnalyticMS_DN_udm_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20200808_144312_33_2257_3B_AnalyticMS_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20200808_144312_33_2257_3B_AnalyticMS_DN_udm_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20201210_153416_55_2416_3B_AnalyticMS_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\20201210_153416_55_2416_3B_AnalyticMS_DN_udm_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\2197304_1843614_2019-03-12_100d_BGRN_Analytic_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\2197304_1843614_2019-03-12_100d_BGRN_DN_udm_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\2939795_1843614_2019-12-16_0f33_BGRN_Analytic_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\2939795_1843614_2019-12-16_0f33_BGRN_DN_udm_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\4026516_1843614_2020-12-29_1025_BGRN_Analytic_clip.tif
# E:\GDrive\TRABAJOS\FAO\8_RESTORATION\1_DATA\COLOMBIA\TEST_AREAS\RestauracionBosqueRipario_BioCaribe\imagery\planet\files\raw\4026516_1843614_2020-12-29_1025_BGRN_DN_udm_clip.tif

# %%
dir(img)
# Out:
# ['__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__fspath__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__truediv__',
#  '_accessor',
#  '_cached_cparts',
#  '_closed',
#  '_cparts',
#  '_drv',
#  '_flavour',
#  '_format_parsed_parts',
#  '_from_parsed_parts',
#  '_from_parts',
#  '_hash',
#  '_init',
#  '_make_child',
#  '_make_child_relpath',
#  '_opener',
#  '_parse_args',
#  '_parts',
#  '_pparts',
#  '_raise_closed',
#  '_raw_open',
#  '_root',
#  '_str',
#  'absolute',
#  'anchor',
#  'as_posix',
#  'as_uri',
#  'chmod',
#  'cwd',
#  'drive',
#  'exists',
#  'expanduser',
#  'glob',
#  'group',
#  'home',
#  'is_absolute',
#  'is_block_device',
#  'is_char_device',
#  'is_dir',
#  'is_fifo',
#  'is_file',
#  'is_mount',
#  'is_reserved',
#  'is_socket',
#  'is_symlink',
#  'iterdir',
#  'joinpath',
#  'lchmod',
#  'link_to',
#  'lstat',
#  'match',
#  'mkdir',
#  'name',
#  'open',
#  'owner',
#  'parent',
#  'parents',
#  'parts',
#  'read_bytes',
#  'read_text',
#  'relative_to',
#  'rename',
#  'replace',
#  'resolve',
#  'rglob',
#  'rmdir',
#  'root',
#  'samefile',
#  'stat',
#  'stem',
#  'suffix',
#  'suffixes',
#  'symlink_to',
#  'touch',
#  'unlink',
#  'with_name',
#  'with_suffix',
#  'write_bytes',
#  'write_text']

# %%
file_name = os.path.basename(zip_info.filename)

split_name = file_name.split('_')

if '3B' in file_name:
    date = pd.to_datetime(split_name[0])
elif 'BGRN' in file_name or 'BGREN' in file_name:
    date = pd.to_datetime(split_name[2])
elif 'RE' in file_name:
    date = pd.to_datetime(split_name[1])
elif 'RGB' in file_name:
    date = pd.to_datetime(split_name[2])

date = date.strftime('%Y_%m_%d')


zip_info.filename  = os.path.join(
                                  os.path.basename(archive.filename)[:-4], 
                                  f'{date}_{os.path.basename(zip_info.filename)}')

archive.extract(zip_info, destination_folder)
